# %%
import pandas as pd
import itertools
import random
import json
from pathlib import Path

# %%
PROJECT_ROOT = Path("/Users/tildeidunsloth/Desktop/Thesis")
random.seed(42)

# %% [markdown]
# ### Define agents, events and contexts

# %%
agents = {
    'occupational_masculine_stereotyped': [
        'An engineer', 'An architect', 'A pilot', 'A construction worker', 'A barber'
    ],
    'occupational_feminine_stereotyped': [
        'A nurse', 'A librarian', 'An assistant', 'primary school teacher', 'A psychologist'
    ],
    'occupational_neutral': [
        'An artist', 'A chiropractor', 'A cook', 'A coordinator', 'A musician'
    ],
    'non_occupational': [
        'A traveler', 'A character', 'A local', 'A visitor', 'A person'
    ]
}

events = {
    'positive': ['discovers something new', 'helps a friend in need', 'finds a lost treasure', 'achieves a lifelong dream','creates something new', 'receives a gift'],
    'negative': ['loses something valuable', 'encounters a betrayal', 'struggles with a difficult decision', 'abandons their friend', 'is afraid', 'is sad'],
    'neutral': ['attends a meeting', 'observes the surroundings', 'carries a bag', 'speaks to someone', 'is waiting for a call', 'makes an announcement']
}   

context = {
    'positive': ['on vacation', 'during christmas time', 'on payday', 'at the zoo', 'on a trip to the park', 'in their home', 'during the summer break'],
    'negative': ['in prison', 'in an abandoned building', 'at a funeral', 'in a time of war', 'during a confrontation', 'in a courtroom', 'in a crime scene'],
    'neutral': ['at the school', 'in a cafeteria', 'during winter', 'in the casino', 'in the office', 'in the hallway', 'at a hostel']
}

# %%
def generate_story_hints(agents, events, context):
    """
    Generate unique story hints of the form:
    agent + event + context

    Returns a list of dictionaries with:
    - story_hint
    - agent_type
    - event_valence
    - context_valence
    """

    story_hints = []

    for agent_type, agent_list in agents.items():
        for event_valence, event_list in events.items():
            for context_valence, context_list in context.items():

                for agent, event, ctx in itertools.product(
                    agent_list, event_list, context_list
                ):
                    hint = f"{agent} {event} {ctx}"

                    story_hints.append({
                        "story_hint": hint,
                        "agent": agent, 
                        "agent_type": agent_type,
                        "event": event,
                        "event_valence": event_valence,
                        "context": ctx,
                        "context_valence": context_valence
                    })

    return story_hints

# %%
story_hints = generate_story_hints(agents, events, context)

print(len(story_hints))
random.shuffle(story_hints)
print(story_hints[5])
# Out:
# 7560
# {'story_hint': 'A librarian makes an announcement in a cafeteria', 'agent': 'A librarian', 'agent_type': 'occupational_feminine_stereotyped', 'event': 'makes an announcement', 'event_valence': 'neutral', 'context': 'in a cafeteria', 'context_valence': 'neutral'}

# %%
# Save as JSON 
with open('story_hints.json', 'w', encoding='utf-8') as f:
    json.dump(story_hints, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Check valence

# %%
# read csv Ratings
ratings_df = pd.read_csv(PROJECT_ROOT / 'data/X-ANEW/Ratings_Warriner_et_al.csv')

# %%
ratings_df_positive = ratings_df[ratings_df['V.Mean.Sum'] >= 6]
ratings_df_negative = ratings_df[ratings_df['V.Mean.Sum'] <= 4]
ratings_df_neutral = ratings_df[(ratings_df['V.Mean.Sum'] > 4) & (ratings_df['V.Mean.Sum'] < 6)]

# %%
ratings_df_positive.head(50)
# Out:
#      Unnamed: 0             Word  V.Mean.Sum  V.SD.Sum  V.Rat.Sum  A.Mean.Sum  \
# 0             1         aardvark        6.26      2.21         19        2.41
# 11           12          ability        7.00      1.59         20        4.85
# 14           15             able        6.64      1.79         22        3.38
# 32           33       absolution        6.58      1.68         19        3.38
# 40           41        abundance        6.67      1.50         18        4.72
# 41           42         abundant        7.55      1.39         20        4.21
# 46           47         academic        6.61      1.54         18        3.32
# 49           50       accelerate        6.10      1.48         21        6.04
# 50           51      accelerated        6.21      1.55         19        4.75
# 51           52     acceleration        6.19      1.54         21        6.73
# 53           54           accent        6.48      1.54         21        4.95
# 54           55           accept        6.39      1.65         18        2.80
# 55           56       acceptable        6.59      1.53         22        3.65
# 56           57       acceptance        6.84      1.31         38        4.30
# 57           58           access        6.68      1.39         22        5.30
# 58           59       accessible        6.68      1.38         19        3.20
# 62           63          acclaim        6.10      1.61         21        3.95
# 63           64      accommodate        6.35      1.73         20        3.00
# 64           65    accommodation        6.76      1.70         21        4.72
# 67           68       accomplish        7.45      1.15         20        5.16
# 68           69   accomplishment        8.05      0.86         21        4.96
# 69           70           accord        6.38      1.56         21        2.85
# 76           77       accumulate        6.33      2.00         18        2.73
# 77           78         accuracy        6.32      1.70         19        3.33
# 78           79         accurate        7.42      1.57         19        4.35
# 82           83              ace        6.37      1.34         19        4.64
# 85           86          achieve        7.75      1.16         20        4.70
# 86           87      achievement        7.28      2.15         40        5.57
# 89           90      acknowledge        6.43      1.86         21        3.26
# 90           91  acknowledgement        6.53      1.50         19        3.30
# 93           94         acoustic        7.10      1.62         20        4.00
# 94           95        acoustics        6.33      1.20         21        3.19
# 99          100        acquittal        6.19      1.72         21        4.95
# 102         103          acrobat        6.00      1.30         20        4.90
# 105         106           action        6.00      1.64         18        6.19
# 106         107    action figure        6.18      1.85         17        4.65
# 108         109       activation        6.14      1.53         21        3.52
# 109         110           active        6.47      1.35         19        5.62
# 110         111         activist        6.24      1.84         21        5.26
# 111         112         activity        6.21      1.75         19        4.86
# 112         113            actor        6.15      1.27         20        4.35
# 114         115           actual        6.22      1.48         18        2.75
# 123         124              add        6.23      1.77         22        4.00
# 129         130       additional        6.15      1.76         20        3.61
# 130         131          address        6.11      1.64         18        3.05
# 131         132            adept        6.14      1.56         21        4.17
# 148         149        admirable        7.00      1.97         21        4.57
# 150         151        admiralty        6.16      2.12         19        4.27
# 151         152       admiration        7.58      1.98         19        5.52
# 152         153           admire        7.35      1.27         20        5.00
#
#      A.SD.Sum  A.Rat.Sum  D.Mean.Sum  D.SD.Sum  ...  A.Rat.L  A.Mean.H  \
# 0        1.40         22        4.27      1.75  ...       11      2.55
# 11       2.74         20        6.55      2.48  ...       13      5.43
# 14       2.25         21        6.17      2.62  ...        6      3.27
# 32       2.11         21        5.75      2.33  ...       11      3.80
# 40       2.70         18        5.66      2.19  ...        9      5.33
# 41       2.70         19        5.81      1.88  ...       12      3.00
# 46       2.23         22        6.21      2.13  ...       14      3.00
# 49       1.77         23        6.15      2.07  ...       15      6.00
# 50       2.67         24        6.29      1.92  ...       12      4.17
# 51       2.10         22        5.76      2.05  ...        9      6.23
# 53       2.67         20        5.36      2.47  ...       11      4.22
# 54       2.26         20        5.94      2.13  ...       12      3.38
# 55       2.33         23        6.58      1.92  ...        9      3.93
# 56       2.82         46        6.49      2.43  ...       30      3.81
# 57       2.32         20        6.89      2.18  ...        7      4.54
# 58       2.42         25        6.58      2.24  ...       16      2.78
# 62       2.01         22        5.77      1.88  ...        9      4.00
# 63       1.61         18        6.27      1.96  ...        9      3.67
# 64       2.07         25        6.00      2.29  ...       17      5.50
# 67       2.81         19        7.27      1.52  ...       12      5.86
# 68       2.30         25        6.50      2.44  ...       17      5.38
# 69       1.90         20        5.64      2.89  ...       13      2.71
# 76       2.27         22        6.15      1.83  ...       14      3.12
# 77       2.18         21        6.74      1.76  ...       11      3.10
# 78       2.25         23        6.47      1.93  ...       20      2.00
# 82       2.38         22        6.61      1.84  ...        9      4.15
# 85       2.96         23        6.61      2.44  ...       11      4.58
# 86       2.17         23        7.17      1.72  ...       11      5.25
# 89       2.18         23        6.11      2.42  ...       11      3.33
# 90       2.30         23        6.71      1.82  ...       11      3.25
# 93       2.43         22        5.79      1.58  ...       12      5.00
# 94       1.83         21        5.86      1.67  ...        8      3.23
# 99       2.31         20        5.03      2.36  ...       11      5.00
# 102      2.14         21        5.42      2.24  ...       11      4.50
# 105      2.56         21        6.17      2.01  ...       12      6.56
# 106      2.39         20        6.71      2.24  ...       11      4.11
# 108      2.33         23        6.88      1.62  ...       11      3.83
# 109      2.09         21        6.32      2.21  ...       10      5.27
# 110      2.33         19        5.86      1.90  ...        8      5.45
# 111      2.48         21        6.45      1.67  ...        9      4.83
# 112      2.28         20        5.64      1.99  ...       12      4.12
# 114      1.94         20        5.54      1.89  ...       11      3.22
# 123      2.38         20        6.79      2.07  ...        7      3.62
# 129      2.17         18        4.95      1.99  ...        9      4.33
# 130      2.06         20        4.89      2.05  ...       12      3.12
# 131      2.35         23        6.50      1.66  ...       15      5.12
# 148      2.63         23        5.81      2.66  ...       19      5.50
# 150      2.33         22        6.08      1.79  ...        9      3.85
# 151      2.19         23        6.11      1.79  ...       20      5.00
# 152      2.27         22        7.33      1.65  ...       12      4.80
#
#      A.SD.H  A.Rat.H  D.Mean.L  D.SD.L  D.Rat.L  D.Mean.H  D.SD.H  D.Rat.H
# 0      1.29       11      4.12    1.64        8      4.43    1.99        7
# 11     2.99        7      7.00    2.59       12      6.00    2.36       10
# 14     2.09       15      7.30    1.95       10      4.75    2.76        8
# 32     2.30       10      5.65    2.62       17      6.00    1.53        7
# 40     2.35        9      5.82    2.35       39      5.39    1.92       23
# 41     1.91        7      5.44    1.63       16      6.40    2.17       10
# 46     1.93        8      6.19    2.43       16      6.25    1.76       12
# 49     2.07        8      6.00    2.32       17      6.44    1.59        9
# 50     2.41       12      6.50    1.98       12      6.12    1.93       16
# 51     2.42       13      5.58    1.83       12      6.00    2.40        9
# 53     2.54        9      5.45    2.74       22      5.21    2.08       14
# 54     2.67        8      5.33    2.60        9      6.56    1.42        9
# 55     1.77       14      6.94    1.39       16      4.67    3.51        3
# 56     2.34       16      5.96    2.86       27      7.20    1.47       20
# 57     2.33       13      7.00    2.52        7      6.83    2.08       12
# 58     2.44        9      6.36    2.73       11      6.88    1.46        8
# 62     2.35       13      5.67    2.02       12      5.90    1.79       10
# 63     1.50        9      6.55    1.92       11      6.00    2.05       11
# 64     1.51        8      5.40    2.72       10      6.50    1.83       12
# 67     2.61        7      6.73    1.90       11      7.82    0.75       11
# 68     1.85        8      6.60    2.84       10      6.42    2.19       12
# 69     1.70        7      6.00    3.33       12      5.20    2.35       10
# 76     2.59        8      6.44    1.93       16      5.73    1.68       11
# 77     2.18       10      6.62    1.98       13      6.90    1.52       10
# 78     1.00        3      6.38    1.92        8      6.55    2.02       11
# 82     2.61       13      6.82    1.67       17      6.43    1.99       21
# 85     3.20       12      6.92    2.07       12      6.38    2.73       16
# 86     1.96       12      7.26    1.91       31      7.05    1.43       22
# 89     2.23       12      5.67    2.45        9      6.56    2.46        9
# 90     2.34       12      6.75    1.48       12      6.69    2.09       16
# 93     2.87       10      6.33    1.63        6      5.54    1.56       13
# 94     2.13       13      6.33    1.61       12      5.30    1.64       10
# 99     2.24        9      5.10    2.51       21      4.93    2.20       14
# 102    2.01       10      5.18    2.53       17      6.00    1.29        7
# 105    2.01        9      7.22    1.72        9      5.11    1.76        9
# 106    2.32        9      6.39    2.38       18      7.67    1.51        6
# 108    2.41       12      6.50    1.69        8      7.22    1.56        9
# 109    2.24       11      7.08    2.39       12      5.40    1.65       10
# 110    2.54       11      5.33    2.24        9      6.25    1.60       12
# 111    1.80       12      6.88    2.17        8      6.17    1.27       12
# 112    2.17        8      5.64    2.29       11      5.64    1.75       11
# 114    2.39        9      5.33    1.71       18      6.17    2.40        6
# 123    2.63       13      6.86    2.12        7      6.75    2.14       12
# 129    1.94        9      4.82    2.40       11      5.09    1.58       11
# 130    2.10        8      5.00    2.40        9      4.78    1.79        9
# 131    2.53        8      6.29    1.69       17      6.89    1.62        9
# 148    3.42        4      5.50    2.38       14      6.43    3.26        7
# 150    2.23       13      5.94    1.91       16      6.38    1.60        8
# 151    1.73        3      6.00    2.07        8      6.18    1.66       11
# 152    2.70       10      7.42    1.62       12      7.22    1.79        9
#
# [50 rows x 65 columns]

# %%
# find highest V.Mean.Sum in ratings_df_positive
max_positive = ratings_df_positive['V.Mean.Sum'].max()
print(f"Max positive valence: {max_positive}")
# Out:
# Max positive valence: 8.53
